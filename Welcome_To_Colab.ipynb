# %% [markdown]
# <a href="https://colab.research.google.com/github/JamieLau-118/testing/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
def hello():
  return "hi"
hello()
# Out:
# 'hi'

# %% [markdown]
# # EDA

# %%
def nigga():
  return "nigga"

nigga()
# Out:
# 'nigga'
